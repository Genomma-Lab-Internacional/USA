# %% [markdown]
# # Libraries

# %%
import os
import pandas as pd
from datetime import datetime
pd.io.formats.excel.ExcelFormatter.header_style = None
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Parameters

# %%
today = datetime.today()
year = today.year
week = today.isocalendar()[1]

# %% [markdown]
# # Import Data

# %%
path = r'\\NASPRO.infovisiontv.com\DWH01\Cognos\Genomma lab USA\US Data\VIP Suerox\{0}\W {1} {0}'
path = path.format(year, str(week).zfill(2))
filename = '{0}_{1}_VIP.xlsx'
filename = filename.format(year, str(week).zfill(2))

# %%
files = [f for f in os.listdir(path) if f != filename]

# %%
files
# Out:
# ['Suerox PR VTM Sell-out Wk 7 2-14-22 without CVS WAGs and WMT.xlsx',
#  'Suerox SO Week 7 for USA and PR (breakdown) 2-14-22.xlsx',
#  'Weekly SO - by detail.csv']

# %%
df_pr = pd.read_excel(
    path + '\\Suerox PR VTM Sell-out Wk 7 2-14-22 without CVS WAGs and WMT.xlsx', 
    header= 3
)

# %%
df_pr
# Out:
#    Week             Distributor Retail Accounts  \
# 0  7.00  Vaqueria Tres Monjitas   Tres Monjitas
# 1  7.00  Vaqueria Tres Monjitas   Tres Monjitas
# 2  7.00  Vaqueria Tres Monjitas   Tres Monjitas
# 3  7.00  Vaqueria Tres Monjitas   Tres Monjitas
# 4  7.00  Vaqueria Tres Monjitas   Tres Monjitas
# 5   NaN                     NaN             NaN
#
#                                        Address      City State  Zip Code  \
# 0  215 Federico Costa, Urb. Ind. Tres Monjitas  Hato Rey    PR    918.00
# 1  215 Federico Costa, Urb. Ind. Tres Monjitas  Hato Rey    PR    918.00
# 2  215 Federico Costa, Urb. Ind. Tres Monjitas  Hato Rey    PR    918.00
# 3  215 Federico Costa, Urb. Ind. Tres Monjitas  Hato Rey    PR    918.00
# 4  215 Federico Costa, Urb. Ind. Tres Monjitas  Hato Rey    PR    918.00
# 5                                          NaN       NaN   NaN       NaN
#
#    Unnamed: 7                UPC                   Product Description  \
# 0         NaN 650,066,003,226.00       SUEROX BLUEBERRY REBOOT 21.3 OZ
# 1         NaN 650,066,003,288.00            SUEROX GRAPE BOOST 21.3 OZ
# 2         NaN 650,066,003,264.00          SUEROX ORANGE RESCUE 21.3 OZ
# 3         NaN 650,066,003,240.00  SUEROX STRAWBERRY/KIWI PUNCH 21.3 OZ
# 4         NaN 650,240,058,684.00        SUEROX COCONUT REFRESH 21.3 OZ
# 5         NaN                NaN                           Grand Total
#
#      Cases  Units   Dollars
# 0   238.17   2858  4,001.20
# 1   236.83   2842  3,978.80
# 2   184.75   2217  3,103.80
# 3   251.00   3012  4,216.80
# 4   155.25   1863  2,608.20
# 5 1,066.00  12792 17,908.80

# %%
df_pr.dropna(axis=)
# Out:
#                     Product Description    Cases  Units   Dollars
# 0       SUEROX BLUEBERRY REBOOT 21.3 OZ   238.17   2858  4,001.20
# 1            SUEROX GRAPE BOOST 21.3 OZ   236.83   2842  3,978.80
# 2          SUEROX ORANGE RESCUE 21.3 OZ   184.75   2217  3,103.80
# 3  SUEROX STRAWBERRY/KIWI PUNCH 21.3 OZ   251.00   3012  4,216.80
# 4        SUEROX COCONUT REFRESH 21.3 OZ   155.25   1863  2,608.20
# 5                           Grand Total 1,066.00  12792 17,908.80

# %%
df = pd.DataFrame()
for file in files:
    try:
        aux = pd.read_excel(path + '\\' + file)
    except:
        aux = pd.read_csv(path + '\\' + file)
    df = pd.concat([df, aux])

# %%
df
# Out:
#      Puerto Rico Suerox Sell-out Week 7 2022              Unnamed: 1  \
# 0                                        NaN                     NaN
# 1                                        NaN                     NaN
# 2                                       Week             Distributor
# 3                                          7  Vaqueria Tres Monjitas
# 4                                          7  Vaqueria Tres Monjitas
# ...                                      ...                     ...
# 1737                                     NaN     ST JOSEPH FOOD MART
# 1738                                     NaN     ST JOSEPH FOOD MART
# 1739                                     NaN          MD MINI MARKET
# 1740                                     NaN          MD MINI MARKET
# 1741                                     NaN            SNAPPY FOODS
#
#                   Unnamed: 2                                   Unnamed: 3  \
# 0                        NaN                                          NaN
# 1                        NaN                                          NaN
# 2            Retail Accounts                                      Address
# 3              Tres Monjitas  215 Federico Costa, Urb. Ind. Tres Monjitas
# 4              Tres Monjitas  215 Federico Costa, Urb. Ind. Tres Monjitas
# ...                      ...                                          ...
# 1737  1817 N SAINT JOSEPH ST                                     GONZALES
# 1738  1817 N SAINT JOSEPH ST                                     GONZALES
# 1739        6658 BOULDER HWY                                    LAS VEGAS
# 1740        6658 BOULDER HWY                                    LAS VEGAS
# 1741       2607 N HIGHWAY 35                                 ARANSAS PASS
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0           NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN
# 2          City      State   Zip Code        NaN
# 3      Hato Rey         PR      00918        NaN
# 4      Hato Rey         PR      00918        NaN
# ...         ...        ...        ...        ...
# 1737         TX      78629        NaN    3265418
# 1738         TX      78629        NaN    3265418
# 1739         NV      89122        NaN    2882224
# 1740         NV      89122        NaN    2882224
# 1741         TX      78336        NaN    2399448
#
#                             Unnamed: 8                       Unnamed: 9  ...  \
# 0                                  NaN                              NaN  ...
# 1                                  NaN                              NaN  ...
# 2                                  UPC              Product Description  ...
# 3                         650066003226  SUEROX BLUEBERRY REBOOT 21.3 OZ  ...
# 4                         650066003288       SUEROX GRAPE BOOST 21.3 OZ  ...
# ...                                ...                              ...  ...
# 1737            SueroX Grape 21oz/12ct                  ="650066003288"  ...
# 1738        SueroX Blueberry 21oz/12ct                  ="650066003226"  ...
# 1739  SueroX Strawberry Kiwi 21oz/12ct                  ="650066003240"  ...
# 1740           SueroX Orange 21oz/12ct                  ="650066003264"  ...
# 1741        SueroX Blueberry 21oz/12ct                  ="650066003226"  ...
#
#                                    Unnamed: 0 Unnamed: 13 Unnamed: 14  \
# 0                                         NaN         NaN         NaN
# 1                                         NaN         NaN         NaN
# 2                                         NaN         NaN         NaN
# 3                                         NaN         NaN         NaN
# 4                                         NaN         NaN         NaN
# ...                                       ...         ...         ...
# 1737        L & F Distributors - Beeville, TX         NaN         NaN
# 1738        L & F Distributors - Beeville, TX         NaN         NaN
# 1739          Nevada Beverage - Tropicana, NV         NaN         NaN
# 1740          Nevada Beverage - Tropicana, NV         NaN         NaN
# 1741  L & F Distributors - Corpus Christi, TX         NaN         NaN
#
#      Unnamed: 15 Unnamed: 16  Unnamed: 17  Unnamed: 18  No Filters Selected  \
# 0            NaN         NaN          NaN          NaN                  NaN
# 1            NaN         NaN          NaN          NaN                  NaN
# 2            NaN         NaN          NaN          NaN                  NaN
# 3            NaN         NaN          NaN          NaN                  NaN
# 4            NaN         NaN          NaN          NaN                  NaN
# ...          ...         ...          ...          ...                  ...
# 1737         NaN         NaN          NaN          NaN                    1
# 1738         NaN         NaN          NaN          NaN                    1
# 1739         NaN         NaN          NaN          NaN                    1
# 1740         NaN         NaN          NaN          NaN                    1
# 1741         NaN         NaN          NaN          NaN                    2
#
#       Calculated Column  Calculated Column.1
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN                  NaN
# 3                   NaN                  NaN
# 4                   NaN                  NaN
# ...                 ...                  ...
# 1737                 12                 16.8
# 1738                 12                 16.8
# 1739                 12                 16.8
# 1740                 12                 16.8
# 1741                 24                 33.6
#
# [1768 rows x 23 columns]
